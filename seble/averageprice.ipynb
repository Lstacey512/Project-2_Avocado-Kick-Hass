# %%
import pandas as pd
data=pd.read_csv(r"C:/Users/seble/Desktop/project2/avocado.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
is_2018=data['year']==2018

# %%
data=data[is_2018]

# %%
data.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 8478           0  2018-03-25          1.57     149396.50  16361.69  109045.03
# 8479           1  2018-03-18          1.35     105304.65  13234.86   61037.58
# 8480           2  2018-03-11          1.12     144648.75  15823.35  110950.68
# 8481           3  2018-03-04          1.08     139520.60  12002.12  105069.57
# 8482           4  2018-02-25          1.28     104278.89  10368.77   59723.32
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 8478  65.45    23924.33    19273.80     4270.53       380.00  conventional
# 8479  55.00    30977.21    26755.90     3721.31       500.00  conventional
# 8480  70.00    17804.72    14480.52     3033.09       291.11  conventional
# 8481  95.62    22353.29    16128.51     5941.45       283.33  conventional
# 8482  48.00    34138.80    30126.31     3702.49       310.00  conventional
#
#       year  region
# 8478  2018  Albany
# ...

# %%
print(is_2018.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: year, dtype: bool

# %%
is_2018=data[data['year']==2018]

# %%
is_2018
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046  \
# 8478            0  2018-03-25          1.57     149396.50  16361.69
# 8479            1  2018-03-18          1.35     105304.65  13234.86
# 8480            2  2018-03-11          1.12     144648.75  15823.35
# 8481            3  2018-03-04          1.08     139520.60  12002.12
# 8482            4  2018-02-25          1.28     104278.89  10368.77
# ...           ...         ...           ...           ...       ...
# 18244           7  2018-02-04          1.63      17074.83   2046.96
# 18245           8  2018-01-28          1.71      13888.04   1191.70
# 18246           9  2018-01-21          1.87      13766.76   1191.92
# 18247          10  2018-01-14          1.93      16205.22   1527.63
# 18248          11  2018-01-07          1.62      17489.58   2894.77
#
#             4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 8478   109045.03   65.45    23924.33    19273.80     4270.53       380.00
# ...

# %% [markdown]
# groupbed = df.groupby('region')

# %%
is_2018.groupby(['region']).sum()
# Out:
#                      Unnamed: 0  AveragePrice  Total Volume          4046  \
# region
# Albany                      132         34.46  1.541986e+06  1.077418e+05
# Atlanta                     132         30.93  8.231422e+06  3.732684e+06
# BaltimoreWashington         132         33.08  1.215890e+07  1.324967e+06
# Boise                       132         35.82  1.214760e+06  5.446050e+05
# Boston                      132         37.84  8.637006e+06  2.275544e+05
# BuffaloRochester            132         29.43  2.123818e+06  1.550381e+05
# California                  132         33.87  8.374131e+07  3.025833e+07
# Charlotte                   132         35.58  3.585890e+06  8.281903e+05
# Chicago                     132         37.48  1.161423e+07  1.400836e+06
# CincinnatiDayton            132         30.62  3.598287e+06  9.408318e+05
# Columbus                    132         28.12  2.843900e+06  8.874644e+05
# DallasFtWorth               132         26.47  1.817175e+07  8.854022e+06
# ...

# %%
summary_table = is_2018.groupby('region')['AveragePrice'].mean().to_frame()

# %%
summary_table = summary_table.sort_values(['AveragePrice'], ascending=False)

# %%
summary_table
# Out:
#                      AveragePrice
# region
# HartfordSpringfield      1.677500
# Boston                   1.576667
# NewYork                  1.574583
# Chicago                  1.561667
# SanFrancisco             1.549583
# RaleighGreensboro        1.535000
# Boise                    1.492500
# Charlotte                1.482500
# SanDiego                 1.477917
# Northeast                1.474167
# Sacramento               1.472083
# StLouis                  1.465833
# Jacksonville             1.456667
# Seattle                  1.455000
# Philadelphia             1.448750
# Albany                   1.435833
# Spokane                  1.425000
# NorthernNewEngland       1.421250
# California               1.411250
# Portland                 1.396250
# LasVegas                 1.393750
# BaltimoreWashington      1.378333
# Plains                   1.359583
# Midsouth                 1.358333
# Orlando                  1.354583
# LosAngeles               1.351667
# ...

# %%
top_5=summary_table[:5]
top_5
# Out:
#                      AveragePrice
# region
# HartfordSpringfield      1.677500
# Boston                   1.576667
# NewYork                  1.574583
# Chicago                  1.561667
# SanFrancisco             1.549583

# %%
bottom_5=summary_table[-5:]
bottom_5
# Out:
#                AveragePrice
# region
# Indianapolis       1.168333
# PhoenixTucson      1.155000
# SouthCentral       1.104583
# DallasFtWorth      1.102917
# Houston            1.042083

# %%
to_drop = ["California","GreatLakes","Midsouth","Northeast","NortherNewEngland","Plains","SouthCarolina","Southeast","SouthCentral","TotalUS","West","WestTexNewMexico"]

# %%
summary_table=summary_table.drop(["California","GreatLakes","Midsouth","Northeast","NorthernNewEngland","Plains","SouthCarolina","Southeast","SouthCentral","TotalUS","West","WestTexNewMexico"])

# %%
bottom_5=summary_table[-5:]
bottom_5
# Out:
#                AveragePrice
# region
# Columbus           1.171667
# Indianapolis       1.168333
# PhoenixTucson      1.155000
# DallasFtWorth      1.102917
# Houston            1.042083

# %%
top_5=summary_table[:5]
top_5
# Out:
#                      AveragePrice
# region
# HartfordSpringfield      1.677500
# Boston                   1.576667
# NewYork                  1.574583
# Chicago                  1.561667
# SanFrancisco             1.549583

# %%
finaltable=pd.DataFrame([top_5, bottom_5])
finaltable.head()
# Out:
#                                                    0
# 0                       AveragePrice
# region      ...
# 1                 AveragePrice
# region            ...

# %%
final_table=pd.concat([top_5, bottom_5]).reset_index()

# %%
final_table.to_html("AveragePrice.html")
