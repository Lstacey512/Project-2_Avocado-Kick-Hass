# %% [markdown]
# # How to Preprocess Florida Avocado Farm Data

# %%
import pandas as pd
import numpy as np
import json

# %%
# Define the filenames we'll use throughout the script
original_geojson_file = "California_Counties.geojson"
new_geojson_file = "Farm_Info_" + original_geojson_file
csv_file = "californiacounties.csv"

# %% [markdown]
# ## Step 1: Take the GeoJSON, extract the counties, and save them to a CSV.

# %%
# Read the original Geojson into a dataframe
df = pd.read_json(original_geojson_file)

# %%
# Pull out each county name and save it to a list (use title case and strip whitespace)
county_list = []
for i in range(len(df)):
    county_name = df.iloc[i,1]['properties']['COUNTY_NAME'].title().strip()
    county_list.append(county_name)
    
print(f"{len(county_list)} counties found.")
# Out:
# 69 counties found.

# %%
# Build a new dataframe based on the list of counties, and create an additional field to indicate 
# whether the county has an avocado farm
county_df = pd.DataFrame({"County": county_list,
                          "HasAvocadoFarm": 0})

# %%
# Sort the list and reset the index
county_df = county_df.sort_values(['County'])
county_df.reset_index(drop=True)
county_df.drop_duplicates(subset=None, keep=False, inplace=True)
county_df
# Out:
#                     County  HasAvocadoFarm
# 0           Alameda County               0
# 1            Alpine County               0
# 2            Amador County               0
# 3             Butte County               0
# 4         Calaveras County               0
# 5            Colusa County               0
# 6      Contra Costa County               0
# 7         Del Norte County               0
# 8         El Dorado County               0
# 9            Fresno County               0
# 10            Glenn County               0
# 11         Humboldt County               0
# 12         Imperial County               0
# 13             Inyo County               0
# 14             Kern County               0
# 15            Kings County               0
# 16             Lake County               0
# 17           Lassen County               0
# 19           Madera County               0
# 20            Marin County               0
# 21         Mariposa County               0
# 22        Mendocino County               0
# 23           Merced County               0
# 24            Modoc County               0
# 25             Mono County               0
# 26         Monterey County               0
# 27             Napa County               0
# 28           Nevada County               0
# 29           Orange County               0
# 30           Placer County               0
# 31           Plumas County               0
# 32        Riverside County               0
# 33       Sacramento County               0
# 34       San Benito County               0
# 35   San Bernardino County               0
# 36        San Diego County               0
# 37    San Francisco County               0
# 38      San Joaquin County               0
# 39  San Luis Obispo County               0
# 40        San Mateo County               0
# 42      Santa Clara County               0
# 43       Santa Cruz County               0
# 44           Shasta County               0
# 45           Sierra County               0
# 46         Siskiyou County               0
# 47           Solano County               0
# 48           Sonoma County               0
# 49       Stanislaus County               0
# 50           Sutter County               0
# 51           Tehama County               0
# 52          Trinity County               0
# 53           Tulare County               0
# 54         Tuolumne County               0
# 56             Yolo County               0
# 57             Yuba County               0

# %%
# Save the dataframe to a CSV
county_df.to_csv(csv_file, index=False, header=True)

# %% [markdown]
# ## Step 2: Manually update the new CSV to set the HasAvocadoFarm field appropriately for each county.
#
# ### NOTE: Use 1 to indicate the county has an avocado farm, and 0 if it doesn't. This is IMPORTANT!

# %%
# Stop here!

# Update the CSV using your favorite editor (Excel works fine) and save it with the same filename. 
# Be sure to CLOSE the file after editing! 

# Once the file CSV is updated and saved, proceed with the next steps.

# %% [markdown]
# ## Step 3: Read the updated CSV into a new dataframe and use it to help modify the contents of the original GeoJSON. The resulting GeoJSON will have a field indicating whether the county in question has an avocado farm. This new field can be used to color the counties as desired.

# %%
# Read the CSV that now contains farm information and set the county as the index, to make it easier to search
county_df = pd.read_csv(csv_file)
county_df = county_df.set_index('County')
county_df.head()
# Out:
#                   HasAvocadoFarm
# County
# Alameda County                 1
# Alpine County                  0
# Amador County                  0
# Butte County                   0
# Calaveras County               0

# %%
county_df
# Out:
#                         HasAvocadoFarm
# County
# Alameda County                       1
# Alpine County                        0
# Amador County                        0
# Butte County                         0
# Calaveras County                     0
# Colusa County                        0
# Contra Costa County                  0
# Del Norte County                     0
# El Dorado County                     0
# Fresno County                        0
# Glenn County                         0
# Humboldt County                      0
# Imperial County                      0
# Inyo County                          0
# Kern County                          0
# Kings County                         0
# Lake County                          0
# Lassen County                        0
# Los Angeles County                   0
# Madera County                        0
# Marin County                         0
# Mariposa County                      0
# Mendocino County                     0
# Merced County                        0
# Modoc County                         0
# Mono County                          0
# Monterey County                      1
# Napa County                          0
# Nevada County                        0
# Orange County                        0
# Placer County                        0
# Plumas County                        0
# Riverside County                     1
# Sacramento County                    0
# San Benito County                    0
# San Bernardino County                1
# San Diego County                     1
# San Francisco County                 0
# San Joaquin County                   0
# San Luis Obispo County               1
# San Mateo County                     0
# Santa Barbara County                 1
# Santa Clara County                   0
# Santa Cruz County                    0
# Shasta County                        0
# Sierra County                        0
# Siskiyou County                      0
# Solano County                        0
# Sonoma County                        0
# Stanislaus County                    0
# Sutter County                        0
# Tehama County                        0
# Trinity County                       0
# Tulare County                        1
# Tuolumne County                      0
# Ventura County                       1
# Yolo County                          0
# Yuba County                          0

# %%
# Update the original GeoJSON dataframe to add a field for avocado farms.
# Initialize this new field based on the information in the CSV.

# For each row in the dataframe ...
for i in range(len(df)):
    
    # ... get the county name, determine the farm status, and update the GeoJSON accordingly
    county_name = df.iloc[i, 1]['properties']['COUNTY_NAME'].title().strip()   
    has_farm = county_df.loc[county_name, 'HasAvocadoFarm']
    df.iloc[i, 1]['properties']['HasAvocadoFarm'] = has_farm

# %%
# Define a helper function to format a GeoJSON
def dfGeoJSON(df):
    geojson = {'type': 'FeatureCollection', 'features': []}
    
    for i in range(len(df)):
        feature = df.iloc[i, 1]
        geojson['features'].append(feature)
    
    return geojson

# %%
# Convert the updated dataframe back to a GeoJSON
geojson = dfGeoJSON(df)

# %%
# Define a helper function to deal with numpy datatypes
def convert(o):
    if isinstance(o, np.int64): return int(o)  
    raise TypeError

# %%
# Finally, save the new GeoJSON file
with open(new_geojson_file, 'w') as file:
     file.write(json.dumps(geojson, default=convert))
